# %%
import matplotlib.pyplot as plt

# %%
x=range(-100,100)
y=[x**2-x+2 for x in x]
plt.text(0,0, '(o,o)')
plt.plot(x,y)
plt.show()

# %%
import math
x=range(-11,11)
y=[math.sqrt(n) for n in x if n=0 return pass]
plt.plot(x,y)
plt.show()
# Out:
#   Input In [112]
#     y=[math.sqrt(n) for n in x if n=0 return pass]
#                                    ^
# SyntaxError: invalid syntax

# %%
import math
x=range(1,11)
y=[n**3 for n in x]
plt.plot(x,y)
plt.show()

# %%
import math
x=range(1,11)
y=[2**n for n in x]
plt.plot(x,y)
plt.show()

# %%
import math
x=range(1,11)
y=[1/(n+1) for n in x]
plt.plot(x,y)
plt.show()

# %%
import math
x=range(1,11)
y=[math.sqrt(n) for n in x]
x1=range(1,11)
y1=[n**3 for n in x1]
x2=range(1,11)
y2=[2**n for n in x2]
x3=range(1,11)
y3=[1/(n+1) for n in x3]
plt.plot(x,y)
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.plot(x3,y3)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
